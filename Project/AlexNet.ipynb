# %% [markdown]
# # To build a model for AlexNet Convolution neural network:

# %%
import tensorflow as tf
import tensorflow.keras.backend as K

# %%
from tensorflow.keras.models import Model

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Input

# %%
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.layers import Flatten

# %%
from tensorflow.keras.layers import Conv2D

# %%
from tensorflow.keras.layers import MaxPooling2D

# %%
from tensorflow.keras.layers import Dropout

# %%
from tensorflow.keras.layers import LeakyReLU

# %%
from tensorflow.keras.layers import Activation

# %%
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(256))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# 2nd Fully Connected Layer
model.add(Dense(96))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# 3rd Fully Connected Layer
model.add(Dense(32))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Output Layer
model.add(Dense(3))
model.add(Activation('softmax'))
model.summary()

# Compile the model
model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy','Precision','Recall','TruePositives','TrueNegatives','FalsePositives','FalseNegatives'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 54, 54, 96)        34944
# _________________________________________________________________
# activation (Activation)      (None, 54, 54, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 69984)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               17916160
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 96)                24672
# _________________________________________________________________
# activation_2 (Activation)    (None, 96)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                3104
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 99
# _________________________________________________________________
# activation_4 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 17,978,979
# Trainable params: 17,978,979
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
training_set=train_datagen.flow_from_directory('Data/train',target_size=(224,224),batch_size=32,class_mode='categorical')
test_set=test_datagen.flow_from_directory('Data/test',target_size=(224,224),batch_size=32,class_mode='categorical')
# Out:
# Found 1448 images belonging to 3 classes.
# Found 1288 images belonging to 3 classes.

# %%
img_dims = 150
epochs = 100
batch_size = 50

# %%
#### Fitting the model
history = model.fit(
           training_set, steps_per_epoch=training_set.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_set,validation_steps=test_set.samples // batch_size)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 28 steps, validate for 25 steps
# Epoch 1/100
# 28/28 [==============================] - 265s 9s/step - loss: 1.2093 - accuracy: 0.3601 - Precision: 0.3286 - Recall: 0.0264 - TruePositives: 23.0000 - TrueNegatives: 1697.0000 - FalsePositives: 47.0000 - FalseNegatives: 849.0000 - val_loss: 1.0957 - val_accuracy: 0.2937 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TruePositives: 0.0000e+00 - val_TrueNegatives: 1600.0000 - val_FalsePositives: 0.0000e+00 - val_FalseNegatives: 800.0000
# Epoch 2/100
# 28/28 [==============================] - 174s 6s/step - loss: 1.0420 - accuracy: 0.5045 - Precision: 0.4667 - Recall: 0.0469 - TruePositives: 42.0000 - TrueNegatives: 1744.0000 - FalsePositives: 48.0000 - FalseNegatives: 854.0000 - val_loss: 0.8495 - val_accuracy: 0.7475 - val_Precision: 0.9423 - val_Recall: 0.0613 - val_TruePositives: 49.0000 - val_TrueNegatives: 1597.0000 - val_FalsePositives: 3.0000 - val_FalseNegatives: 751.0000
# Epoch 3/100
# 28/28 [==============================] - 167s 6s/step - loss: 0.8848 - accuracy: 0.6250 - Precision: 0.6718 - Recall: 0.3382 - TruePositives: 303.0000 - TrueNegatives: 1644.0000 - FalsePositives: 148.0000 - FalseNegatives: 593.0000 - val_loss: 0.5952 - val_accuracy: 0.8725 - val_Precision: 0.9291 - val_Recall: 0.7375 - val_TruePositives: 590.0000 - val_TrueNegatives: 1555.0000 - val_FalsePositives: 45.0000 - val_FalseNegatives: 210.0000
# Epoch 4/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.7779 - accuracy: 0.6931 - Precision: 0.7273 - Recall: 0.5714 - TruePositives: 512.0000 - TrueNegatives: 1600.0000 - FalsePositives: 192.0000 - FalseNegatives: 384.0000 - val_loss: 0.6871 - val_accuracy: 0.8250 - val_Precision: 0.8821 - val_Recall: 0.5425 - val_TruePositives: 434.0000 - val_TrueNegatives: 1542.0000 - val_FalsePositives: 58.0000 - val_FalseNegatives: 366.0000
# Epoch 5/100
# 28/28 [==============================] - 123s 4s/step - loss: 0.6866 - accuracy: 0.7455 - Precision: 0.7865 - Recall: 0.6373 - TruePositives: 571.0000 - TrueNegatives: 1637.0000 - FalsePositives: 155.0000 - FalseNegatives: 325.0000 - val_loss: 0.5344 - val_accuracy: 0.8700 - val_Precision: 0.9120 - val_Recall: 0.7900 - val_TruePositives: 632.0000 - val_TrueNegatives: 1539.0000 - val_FalsePositives: 61.0000 - val_FalseNegatives: 168.0000
# Epoch 6/100
# 28/28 [==============================] - 118s 4s/step - loss: 0.5432 - accuracy: 0.8050 - Precision: 0.8399 - Recall: 0.7523 - TruePositives: 656.0000 - TrueNegatives: 1619.0000 - FalsePositives: 125.0000 - FalseNegatives: 216.0000 - val_loss: 0.6114 - val_accuracy: 0.7462 - val_Precision: 0.7595 - val_Recall: 0.7262 - val_TruePositives: 581.0000 - val_TrueNegatives: 1416.0000 - val_FalsePositives: 184.0000 - val_FalseNegatives: 219.0000
# Epoch 7/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.5376 - accuracy: 0.7959 - Precision: 0.8145 - Recall: 0.7603 - TruePositives: 663.0000 - TrueNegatives: 1593.0000 - FalsePositives: 151.0000 - FalseNegatives: 209.0000 - val_loss: 0.4407 - val_accuracy: 0.8338 - val_Precision: 0.8573 - val_Recall: 0.8112 - val_TruePositives: 649.0000 - val_TrueNegatives: 1492.0000 - val_FalsePositives: 108.0000 - val_FalseNegatives: 151.0000
# Epoch 8/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.5477 - accuracy: 0.8050 - Precision: 0.8397 - Recall: 0.7569 - TruePositives: 660.0000 - TrueNegatives: 1618.0000 - FalsePositives: 126.0000 - FalseNegatives: 212.0000 - val_loss: 0.4455 - val_accuracy: 0.8388 - val_Precision: 0.8606 - val_Recall: 0.8025 - val_TruePositives: 642.0000 - val_TrueNegatives: 1496.0000 - val_FalsePositives: 104.0000 - val_FalseNegatives: 158.0000
# Epoch 9/100
# 28/28 [==============================] - 117s 4s/step - loss: 0.4799 - accuracy: 0.8142 - Precision: 0.8408 - Recall: 0.7936 - TruePositives: 692.0000 - TrueNegatives: 1613.0000 - FalsePositives: 131.0000 - FalseNegatives: 180.0000 - val_loss: 0.4527 - val_accuracy: 0.7800 - val_Precision: 0.8058 - val_Recall: 0.7625 - val_TruePositives: 610.0000 - val_TrueNegatives: 1453.0000 - val_FalsePositives: 147.0000 - val_FalseNegatives: 190.0000
# Epoch 10/100
# 28/28 [==============================] - 117s 4s/step - loss: 0.4539 - accuracy: 0.8509 - Precision: 0.8639 - Recall: 0.8154 - TruePositives: 711.0000 - TrueNegatives: 1632.0000 - FalsePositives: 112.0000 - FalseNegatives: 161.0000 - val_loss: 0.2988 - val_accuracy: 0.8875 - val_Precision: 0.9066 - val_Recall: 0.8737 - val_TruePositives: 699.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 101.0000
# Epoch 11/100
# 28/28 [==============================] - 128s 5s/step - loss: 0.4463 - accuracy: 0.8359 - Precision: 0.8565 - Recall: 0.8058 - TruePositives: 722.0000 - TrueNegatives: 1671.0000 - FalsePositives: 121.0000 - FalseNegatives: 174.0000 - val_loss: 0.3173 - val_accuracy: 0.8650 - val_Precision: 0.8747 - val_Recall: 0.8462 - val_TruePositives: 677.0000 - val_TrueNegatives: 1503.0000 - val_FalsePositives: 97.0000 - val_FalseNegatives: 123.0000
# Epoch 12/100
# 28/28 [==============================] - 129s 5s/step - loss: 0.4444 - accuracy: 0.8257 - Precision: 0.8465 - Recall: 0.7970 - TruePositives: 695.0000 - TrueNegatives: 1618.0000 - FalsePositives: 126.0000 - FalseNegatives: 177.0000 - val_loss: 0.2756 - val_accuracy: 0.8988 - val_Precision: 0.9060 - val_Recall: 0.8913 - val_TruePositives: 713.0000 - val_TrueNegatives: 1526.0000 - val_FalsePositives: 74.0000 - val_FalseNegatives: 87.0000
# Epoch 13/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.3984 - accuracy: 0.8359 - Precision: 0.8519 - Recall: 0.8214 - TruePositives: 736.0000 - TrueNegatives: 1664.0000 - FalsePositives: 128.0000 - FalseNegatives: 160.0000 - val_loss: 0.2459 - val_accuracy: 0.9062 - val_Precision: 0.9151 - val_Recall: 0.9025 - val_TruePositives: 722.0000 - val_TrueNegatives: 1533.0000 - val_FalsePositives: 67.0000 - val_FalseNegatives: 78.0000
# Epoch 14/100
# 28/28 [==============================] - 118s 4s/step - loss: 0.4074 - accuracy: 0.8372 - Precision: 0.8539 - Recall: 0.8177 - TruePositives: 713.0000 - TrueNegatives: 1622.0000 - FalsePositives: 122.0000 - FalseNegatives: 159.0000 - val_loss: 0.3248 - val_accuracy: 0.8838 - val_Precision: 0.8917 - val_Recall: 0.8750 - val_TruePositives: 700.0000 - val_TrueNegatives: 1515.0000 - val_FalsePositives: 85.0000 - val_FalseNegatives: 100.0000
# Epoch 15/100
# 28/28 [==============================] - 116s 4s/step - loss: 0.3864 - accuracy: 0.8404 - Precision: 0.8494 - Recall: 0.8181 - TruePositives: 733.0000 - TrueNegatives: 1662.0000 - FalsePositives: 130.0000 - FalseNegatives: 163.0000 - val_loss: 0.3252 - val_accuracy: 0.8725 - val_Precision: 0.8912 - val_Recall: 0.8500 - val_TruePositives: 680.0000 - val_TrueNegatives: 1517.0000 - val_FalsePositives: 83.0000 - val_FalseNegatives: 120.0000
# Epoch 16/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.3745 - accuracy: 0.8683 - Precision: 0.8785 - Recall: 0.8393 - TruePositives: 752.0000 - TrueNegatives: 1688.0000 - FalsePositives: 104.0000 - FalseNegatives: 144.0000 - val_loss: 0.2979 - val_accuracy: 0.8825 - val_Precision: 0.8899 - val_Recall: 0.8788 - val_TruePositives: 703.0000 - val_TrueNegatives: 1513.0000 - val_FalsePositives: 87.0000 - val_FalseNegatives: 97.0000
# Epoch 17/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.3546 - accuracy: 0.8694 - Precision: 0.8846 - Recall: 0.8471 - TruePositives: 759.0000 - TrueNegatives: 1693.0000 - FalsePositives: 99.0000 - FalseNegatives: 137.0000 - val_loss: 0.2930 - val_accuracy: 0.8863 - val_Precision: 0.8950 - val_Recall: 0.8737 - val_TruePositives: 699.0000 - val_TrueNegatives: 1518.0000 - val_FalsePositives: 82.0000 - val_FalseNegatives: 101.0000
# Epoch 18/100
# 28/28 [==============================] - 118s 4s/step - loss: 0.3810 - accuracy: 0.8527 - Precision: 0.8716 - Recall: 0.8337 - TruePositives: 747.0000 - TrueNegatives: 1682.0000 - FalsePositives: 110.0000 - FalseNegatives: 149.0000 - val_loss: 0.3441 - val_accuracy: 0.8525 - val_Precision: 0.8669 - val_Recall: 0.8388 - val_TruePositives: 671.0000 - val_TrueNegatives: 1497.0000 - val_FalsePositives: 103.0000 - val_FalseNegatives: 129.0000
# Epoch 19/100
# 28/28 [==============================] - 3513s 125s/step - loss: 0.4274 - accuracy: 0.8326 - Precision: 0.8468 - Recall: 0.8050 - TruePositives: 702.0000 - TrueNegatives: 1617.0000 - FalsePositives: 127.0000 - FalseNegatives: 170.0000 - val_loss: 0.3216 - val_accuracy: 0.8850 - val_Precision: 0.8939 - val_Recall: 0.8637 - val_TruePositives: 691.0000 - val_TrueNegatives: 1518.0000 - val_FalsePositives: 82.0000 - val_FalseNegatives: 109.0000
# Epoch 20/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.3994 - accuracy: 0.8589 - Precision: 0.8696 - Recall: 0.8337 - TruePositives: 727.0000 - TrueNegatives: 1635.0000 - FalsePositives: 109.0000 - FalseNegatives: 145.0000 - val_loss: 0.2791 - val_accuracy: 0.9000 - val_Precision: 0.9103 - val_Recall: 0.8875 - val_TruePositives: 710.0000 - val_TrueNegatives: 1530.0000 - val_FalsePositives: 70.0000 - val_FalseNegatives: 90.0000
# Epoch 21/100
# 28/28 [==============================] - 130s 5s/step - loss: 0.3707 - accuracy: 0.8661 - Precision: 0.8698 - Recall: 0.8426 - TruePositives: 755.0000 - TrueNegatives: 1679.0000 - FalsePositives: 113.0000 - FalseNegatives: 141.0000 - val_loss: 0.2869 - val_accuracy: 0.8712 - val_Precision: 0.8793 - val_Recall: 0.8650 - val_TruePositives: 692.0000 - val_TrueNegatives: 1505.0000 - val_FalsePositives: 95.0000 - val_FalseNegatives: 108.0000
# Epoch 22/100
# 28/28 [==============================] - 125s 4s/step - loss: 0.3823 - accuracy: 0.8498 - Precision: 0.8702 - Recall: 0.8303 - TruePositives: 724.0000 - TrueNegatives: 1636.0000 - FalsePositives: 108.0000 - FalseNegatives: 148.0000 - val_loss: 0.3869 - val_accuracy: 0.7987 - val_Precision: 0.8166 - val_Recall: 0.7738 - val_TruePositives: 619.0000 - val_TrueNegatives: 1461.0000 - val_FalsePositives: 139.0000 - val_FalseNegatives: 181.0000
# Epoch 23/100
# 28/28 [==============================] - 125s 4s/step - loss: 0.3244 - accuracy: 0.8865 - Precision: 0.8952 - Recall: 0.8624 - TruePositives: 752.0000 - TrueNegatives: 1656.0000 - FalsePositives: 88.0000 - FalseNegatives: 120.0000 - val_loss: 0.2697 - val_accuracy: 0.8813 - val_Precision: 0.8917 - val_Recall: 0.8750 - val_TruePositives: 700.0000 - val_TrueNegatives: 1515.0000 - val_FalsePositives: 85.0000 - val_FalseNegatives: 100.0000
# Epoch 24/100
# 28/28 [==============================] - 136s 5s/step - loss: 0.3761 - accuracy: 0.8647 - Precision: 0.8799 - Recall: 0.8486 - TruePositives: 740.0000 - TrueNegatives: 1643.0000 - FalsePositives: 101.0000 - FalseNegatives: 132.0000 - val_loss: 0.2709 - val_accuracy: 0.8938 - val_Precision: 0.9077 - val_Recall: 0.8850 - val_TruePositives: 708.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 92.0000
# Epoch 25/100
# 28/28 [==============================] - 123s 4s/step - loss: 0.3033 - accuracy: 0.9014 - Precision: 0.9120 - Recall: 0.8911 - TruePositives: 777.0000 - TrueNegatives: 1669.0000 - FalsePositives: 75.0000 - FalseNegatives: 95.0000 - val_loss: 0.2553 - val_accuracy: 0.9050 - val_Precision: 0.9105 - val_Recall: 0.9025 - val_TruePositives: 722.0000 - val_TrueNegatives: 1529.0000 - val_FalsePositives: 71.0000 - val_FalseNegatives: 78.0000
# Epoch 26/100
# 28/28 [==============================] - 123s 4s/step - loss: 0.3475 - accuracy: 0.8784 - Precision: 0.8837 - Recall: 0.8624 - TruePositives: 752.0000 - TrueNegatives: 1645.0000 - FalsePositives: 99.0000 - FalseNegatives: 120.0000 - val_loss: 0.2922 - val_accuracy: 0.8763 - val_Precision: 0.8836 - val_Recall: 0.8537 - val_TruePositives: 683.0000 - val_TrueNegatives: 1510.0000 - val_FalsePositives: 90.0000 - val_FalseNegatives: 117.0000
# Epoch 27/100
# 28/28 [==============================] - 129s 5s/step - loss: 0.3369 - accuracy: 0.8704 - Precision: 0.8774 - Recall: 0.8532 - TruePositives: 744.0000 - TrueNegatives: 1640.0000 - FalsePositives: 104.0000 - FalseNegatives: 128.0000 - val_loss: 0.2979 - val_accuracy: 0.8650 - val_Precision: 0.8779 - val_Recall: 0.8537 - val_TruePositives: 683.0000 - val_TrueNegatives: 1505.0000 - val_FalsePositives: 95.0000 - val_FalseNegatives: 117.0000
# Epoch 28/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.3584 - accuracy: 0.8683 - Precision: 0.8789 - Recall: 0.8504 - TruePositives: 762.0000 - TrueNegatives: 1687.0000 - FalsePositives: 105.0000 - FalseNegatives: 134.0000 - val_loss: 0.3450 - val_accuracy: 0.8637 - val_Precision: 0.8731 - val_Recall: 0.8512 - val_TruePositives: 681.0000 - val_TrueNegatives: 1501.0000 - val_FalsePositives: 99.0000 - val_FalseNegatives: 119.0000
# Epoch 29/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.3399 - accuracy: 0.8658 - Precision: 0.8774 - Recall: 0.8452 - TruePositives: 737.0000 - TrueNegatives: 1641.0000 - FalsePositives: 103.0000 - FalseNegatives: 135.0000 - val_loss: 0.3037 - val_accuracy: 0.8750 - val_Precision: 0.8825 - val_Recall: 0.8637 - val_TruePositives: 691.0000 - val_TrueNegatives: 1508.0000 - val_FalsePositives: 92.0000 - val_FalseNegatives: 109.0000
# Epoch 30/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.3588 - accuracy: 0.8795 - Precision: 0.8859 - Recall: 0.8583 - TruePositives: 769.0000 - TrueNegatives: 1693.0000 - FalsePositives: 99.0000 - FalseNegatives: 127.0000 - val_loss: 0.3161 - val_accuracy: 0.8675 - val_Precision: 0.8809 - val_Recall: 0.8600 - val_TruePositives: 688.0000 - val_TrueNegatives: 1507.0000 - val_FalsePositives: 93.0000 - val_FalseNegatives: 112.0000
# Epoch 31/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.3723 - accuracy: 0.8670 - Precision: 0.8799 - Recall: 0.8486 - TruePositives: 740.0000 - TrueNegatives: 1643.0000 - FalsePositives: 101.0000 - FalseNegatives: 132.0000 - val_loss: 0.3149 - val_accuracy: 0.8825 - val_Precision: 0.8904 - val_Recall: 0.8737 - val_TruePositives: 699.0000 - val_TrueNegatives: 1514.0000 - val_FalsePositives: 86.0000 - val_FalseNegatives: 101.0000
# Epoch 32/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.4601 - accuracy: 0.8360 - Precision: 0.8496 - Recall: 0.8165 - TruePositives: 712.0000 - TrueNegatives: 1618.0000 - FalsePositives: 126.0000 - FalseNegatives: 160.0000 - val_loss: 0.2774 - val_accuracy: 0.9013 - val_Precision: 0.9126 - val_Recall: 0.8875 - val_TruePositives: 710.0000 - val_TrueNegatives: 1532.0000 - val_FalsePositives: 68.0000 - val_FalseNegatives: 90.0000
# Epoch 33/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.3348 - accuracy: 0.8705 - Precision: 0.8852 - Recall: 0.8516 - TruePositives: 763.0000 - TrueNegatives: 1693.0000 - FalsePositives: 99.0000 - FalseNegatives: 133.0000 - val_loss: 0.2189 - val_accuracy: 0.9175 - val_Precision: 0.9241 - val_Recall: 0.9125 - val_TruePositives: 730.0000 - val_TrueNegatives: 1540.0000 - val_FalsePositives: 60.0000 - val_FalseNegatives: 70.0000
# Epoch 34/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.3913 - accuracy: 0.8509 - Precision: 0.8654 - Recall: 0.8257 - TruePositives: 720.0000 - TrueNegatives: 1632.0000 - FalsePositives: 112.0000 - FalseNegatives: 152.0000 - val_loss: 0.4159 - val_accuracy: 0.8087 - val_Precision: 0.8111 - val_Recall: 0.7887 - val_TruePositives: 631.0000 - val_TrueNegatives: 1453.0000 - val_FalsePositives: 147.0000 - val_FalseNegatives: 169.0000
# Epoch 35/100
# 28/28 [==============================] - 117s 4s/step - loss: 0.3086 - accuracy: 0.8819 - Precision: 0.8910 - Recall: 0.8716 - TruePositives: 760.0000 - TrueNegatives: 1651.0000 - FalsePositives: 93.0000 - FalseNegatives: 112.0000 - val_loss: 0.2493 - val_accuracy: 0.8975 - val_Precision: 0.9024 - val_Recall: 0.8900 - val_TruePositives: 712.0000 - val_TrueNegatives: 1523.0000 - val_FalsePositives: 77.0000 - val_FalseNegatives: 88.0000
# Epoch 36/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2666 - accuracy: 0.9037 - Precision: 0.9079 - Recall: 0.8933 - TruePositives: 779.0000 - TrueNegatives: 1665.0000 - FalsePositives: 79.0000 - FalseNegatives: 93.0000 - val_loss: 0.2509 - val_accuracy: 0.9025 - val_Precision: 0.9091 - val_Recall: 0.9000 - val_TruePositives: 720.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 80.0000
# Epoch 37/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.3286 - accuracy: 0.8819 - Precision: 0.8939 - Recall: 0.8601 - TruePositives: 750.0000 - TrueNegatives: 1655.0000 - FalsePositives: 89.0000 - FalseNegatives: 122.0000 - val_loss: 0.3051 - val_accuracy: 0.8775 - val_Precision: 0.8895 - val_Recall: 0.8650 - val_TruePositives: 692.0000 - val_TrueNegatives: 1514.0000 - val_FalsePositives: 86.0000 - val_FalseNegatives: 108.0000
# Epoch 38/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.3344 - accuracy: 0.8911 - Precision: 0.9076 - Recall: 0.8784 - TruePositives: 766.0000 - TrueNegatives: 1666.0000 - FalsePositives: 78.0000 - FalseNegatives: 106.0000 - val_loss: 0.2756 - val_accuracy: 0.9013 - val_Precision: 0.9071 - val_Recall: 0.8913 - val_TruePositives: 713.0000 - val_TrueNegatives: 1527.0000 - val_FalsePositives: 73.0000 - val_FalseNegatives: 87.0000
# Epoch 39/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.3349 - accuracy: 0.8795 - Precision: 0.8826 - Recall: 0.8560 - TruePositives: 767.0000 - TrueNegatives: 1690.0000 - FalsePositives: 102.0000 - FalseNegatives: 129.0000 - val_loss: 0.2641 - val_accuracy: 0.8925 - val_Precision: 0.9000 - val_Recall: 0.8888 - val_TruePositives: 711.0000 - val_TrueNegatives: 1521.0000 - val_FalsePositives: 79.0000 - val_FalseNegatives: 89.0000
# Epoch 40/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.3085 - accuracy: 0.8895 - Precision: 0.8920 - Recall: 0.8761 - TruePositives: 785.0000 - TrueNegatives: 1697.0000 - FalsePositives: 95.0000 - FalseNegatives: 111.0000 - val_loss: 0.2847 - val_accuracy: 0.8637 - val_Precision: 0.8698 - val_Recall: 0.8600 - val_TruePositives: 688.0000 - val_TrueNegatives: 1497.0000 - val_FalsePositives: 103.0000 - val_FalseNegatives: 112.0000
# Epoch 41/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.3024 - accuracy: 0.8862 - Precision: 0.8913 - Recall: 0.8694 - TruePositives: 779.0000 - TrueNegatives: 1697.0000 - FalsePositives: 95.0000 - FalseNegatives: 117.0000 - val_loss: 0.2888 - val_accuracy: 0.9062 - val_Precision: 0.9084 - val_Recall: 0.9050 - val_TruePositives: 724.0000 - val_TrueNegatives: 1527.0000 - val_FalsePositives: 73.0000 - val_FalseNegatives: 76.0000
# Epoch 42/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2991 - accuracy: 0.8876 - Precision: 0.9007 - Recall: 0.8739 - TruePositives: 762.0000 - TrueNegatives: 1660.0000 - FalsePositives: 84.0000 - FalseNegatives: 110.0000 - val_loss: 0.3550 - val_accuracy: 0.8512 - val_Precision: 0.8541 - val_Recall: 0.8487 - val_TruePositives: 679.0000 - val_TrueNegatives: 1484.0000 - val_FalsePositives: 116.0000 - val_FalseNegatives: 121.0000
# Epoch 43/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2941 - accuracy: 0.8830 - Precision: 0.8915 - Recall: 0.8761 - TruePositives: 764.0000 - TrueNegatives: 1651.0000 - FalsePositives: 93.0000 - FalseNegatives: 108.0000 - val_loss: 0.2282 - val_accuracy: 0.9125 - val_Precision: 0.9165 - val_Recall: 0.9050 - val_TruePositives: 724.0000 - val_TrueNegatives: 1534.0000 - val_FalsePositives: 66.0000 - val_FalseNegatives: 76.0000
# Epoch 44/100
# 28/28 [==============================] - 116s 4s/step - loss: 0.3354 - accuracy: 0.8773 - Precision: 0.8836 - Recall: 0.8704 - TruePositives: 759.0000 - TrueNegatives: 1644.0000 - FalsePositives: 100.0000 - FalseNegatives: 113.0000 - val_loss: 0.3122 - val_accuracy: 0.8750 - val_Precision: 0.8899 - val_Recall: 0.8587 - val_TruePositives: 687.0000 - val_TrueNegatives: 1515.0000 - val_FalsePositives: 85.0000 - val_FalseNegatives: 113.0000
# Epoch 45/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.3209 - accuracy: 0.8933 - Precision: 0.9002 - Recall: 0.8693 - TruePositives: 758.0000 - TrueNegatives: 1660.0000 - FalsePositives: 84.0000 - FalseNegatives: 114.0000 - val_loss: 0.2376 - val_accuracy: 0.9187 - val_Precision: 0.9240 - val_Recall: 0.9112 - val_TruePositives: 729.0000 - val_TrueNegatives: 1540.0000 - val_FalsePositives: 60.0000 - val_FalseNegatives: 71.0000
# Epoch 46/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2905 - accuracy: 0.8911 - Precision: 0.9005 - Recall: 0.8819 - TruePositives: 769.0000 - TrueNegatives: 1659.0000 - FalsePositives: 85.0000 - FalseNegatives: 103.0000 - val_loss: 0.2588 - val_accuracy: 0.8988 - val_Precision: 0.9084 - val_Recall: 0.8925 - val_TruePositives: 714.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 86.0000
# Epoch 47/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2797 - accuracy: 0.9096 - Precision: 0.9146 - Recall: 0.8962 - TruePositives: 803.0000 - TrueNegatives: 1717.0000 - FalsePositives: 75.0000 - FalseNegatives: 93.0000 - val_loss: 0.3260 - val_accuracy: 0.8438 - val_Precision: 0.8506 - val_Recall: 0.8400 - val_TruePositives: 672.0000 - val_TrueNegatives: 1482.0000 - val_FalsePositives: 118.0000 - val_FalseNegatives: 128.0000
# Epoch 48/100
# 28/28 [==============================] - 117s 4s/step - loss: 0.2689 - accuracy: 0.8876 - Precision: 0.9005 - Recall: 0.8819 - TruePositives: 769.0000 - TrueNegatives: 1659.0000 - FalsePositives: 85.0000 - FalseNegatives: 103.0000 - val_loss: 0.3189 - val_accuracy: 0.8625 - val_Precision: 0.8662 - val_Recall: 0.8575 - val_TruePositives: 686.0000 - val_TrueNegatives: 1494.0000 - val_FalsePositives: 106.0000 - val_FalseNegatives: 114.0000
# Epoch 49/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.3049 - accuracy: 0.8933 - Precision: 0.9011 - Recall: 0.8773 - TruePositives: 765.0000 - TrueNegatives: 1660.0000 - FalsePositives: 84.0000 - FalseNegatives: 107.0000 - val_loss: 0.2864 - val_accuracy: 0.8850 - val_Precision: 0.8920 - val_Recall: 0.8775 - val_TruePositives: 702.0000 - val_TrueNegatives: 1515.0000 - val_FalsePositives: 85.0000 - val_FalseNegatives: 98.0000
# Epoch 50/100
# 28/28 [==============================] - 123s 4s/step - loss: 0.2339 - accuracy: 0.9174 - Precision: 0.9301 - Recall: 0.9062 - TruePositives: 812.0000 - TrueNegatives: 1731.0000 - FalsePositives: 61.0000 - FalseNegatives: 84.0000 - val_loss: 0.3209 - val_accuracy: 0.8800 - val_Precision: 0.8838 - val_Recall: 0.8750 - val_TruePositives: 700.0000 - val_TrueNegatives: 1508.0000 - val_FalsePositives: 92.0000 - val_FalseNegatives: 100.0000
# Epoch 51/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2341 - accuracy: 0.9151 - Precision: 0.9189 - Recall: 0.9094 - TruePositives: 793.0000 - TrueNegatives: 1674.0000 - FalsePositives: 70.0000 - FalseNegatives: 79.0000 - val_loss: 0.2401 - val_accuracy: 0.9025 - val_Precision: 0.9092 - val_Recall: 0.9013 - val_TruePositives: 721.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 79.0000
# Epoch 52/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.2728 - accuracy: 0.9037 - Precision: 0.9124 - Recall: 0.8956 - TruePositives: 781.0000 - TrueNegatives: 1669.0000 - FalsePositives: 75.0000 - FalseNegatives: 91.0000 - val_loss: 0.2597 - val_accuracy: 0.8788 - val_Precision: 0.8840 - val_Recall: 0.8763 - val_TruePositives: 701.0000 - val_TrueNegatives: 1508.0000 - val_FalsePositives: 92.0000 - val_FalseNegatives: 99.0000
# Epoch 53/100
# 28/28 [==============================] - 118s 4s/step - loss: 0.3054 - accuracy: 0.8888 - Precision: 0.8914 - Recall: 0.8750 - TruePositives: 763.0000 - TrueNegatives: 1651.0000 - FalsePositives: 93.0000 - FalseNegatives: 109.0000 - val_loss: 0.2586 - val_accuracy: 0.8988 - val_Precision: 0.9108 - val_Recall: 0.8938 - val_TruePositives: 715.0000 - val_TrueNegatives: 1530.0000 - val_FalsePositives: 70.0000 - val_FalseNegatives: 85.0000
# Epoch 54/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.3221 - accuracy: 0.8817 - Precision: 0.8983 - Recall: 0.8672 - TruePositives: 777.0000 - TrueNegatives: 1704.0000 - FalsePositives: 88.0000 - FalseNegatives: 119.0000 - val_loss: 0.3497 - val_accuracy: 0.8363 - val_Precision: 0.8398 - val_Recall: 0.8325 - val_TruePositives: 666.0000 - val_TrueNegatives: 1473.0000 - val_FalsePositives: 127.0000 - val_FalseNegatives: 134.0000
# Epoch 55/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2764 - accuracy: 0.8962 - Precision: 0.8993 - Recall: 0.8873 - TruePositives: 795.0000 - TrueNegatives: 1703.0000 - FalsePositives: 89.0000 - FalseNegatives: 101.0000 - val_loss: 0.2859 - val_accuracy: 0.8863 - val_Precision: 0.8944 - val_Recall: 0.8788 - val_TruePositives: 703.0000 - val_TrueNegatives: 1517.0000 - val_FalsePositives: 83.0000 - val_FalseNegatives: 97.0000
# Epoch 56/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2346 - accuracy: 0.9107 - Precision: 0.9144 - Recall: 0.9062 - TruePositives: 812.0000 - TrueNegatives: 1716.0000 - FalsePositives: 76.0000 - FalseNegatives: 84.0000 - val_loss: 0.2550 - val_accuracy: 0.9062 - val_Precision: 0.9123 - val_Recall: 0.8975 - val_TruePositives: 718.0000 - val_TrueNegatives: 1531.0000 - val_FalsePositives: 69.0000 - val_FalseNegatives: 82.0000
# Epoch 57/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.2905 - accuracy: 0.8899 - Precision: 0.8973 - Recall: 0.8716 - TruePositives: 760.0000 - TrueNegatives: 1657.0000 - FalsePositives: 87.0000 - FalseNegatives: 112.0000 - val_loss: 0.2656 - val_accuracy: 0.8913 - val_Precision: 0.8975 - val_Recall: 0.8863 - val_TruePositives: 709.0000 - val_TrueNegatives: 1519.0000 - val_FalsePositives: 81.0000 - val_FalseNegatives: 91.0000
# Epoch 58/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.3218 - accuracy: 0.8817 - Precision: 0.8867 - Recall: 0.8739 - TruePositives: 783.0000 - TrueNegatives: 1692.0000 - FalsePositives: 100.0000 - FalseNegatives: 113.0000 - val_loss: 0.2378 - val_accuracy: 0.9050 - val_Precision: 0.9113 - val_Recall: 0.8988 - val_TruePositives: 719.0000 - val_TrueNegatives: 1530.0000 - val_FalsePositives: 70.0000 - val_FalseNegatives: 81.0000
# Epoch 59/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2407 - accuracy: 0.9128 - Precision: 0.9243 - Recall: 0.8968 - TruePositives: 782.0000 - TrueNegatives: 1680.0000 - FalsePositives: 64.0000 - FalseNegatives: 90.0000 - val_loss: 0.2274 - val_accuracy: 0.9013 - val_Precision: 0.9099 - val_Recall: 0.8963 - val_TruePositives: 717.0000 - val_TrueNegatives: 1529.0000 - val_FalsePositives: 71.0000 - val_FalseNegatives: 83.0000
# Epoch 60/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2861 - accuracy: 0.8819 - Precision: 0.8931 - Recall: 0.8624 - TruePositives: 752.0000 - TrueNegatives: 1654.0000 - FalsePositives: 90.0000 - FalseNegatives: 120.0000 - val_loss: 0.2334 - val_accuracy: 0.9013 - val_Precision: 0.9179 - val_Recall: 0.8950 - val_TruePositives: 716.0000 - val_TrueNegatives: 1536.0000 - val_FalsePositives: 64.0000 - val_FalseNegatives: 84.0000
# Epoch 61/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.2625 - accuracy: 0.9040 - Precision: 0.9115 - Recall: 0.8962 - TruePositives: 803.0000 - TrueNegatives: 1714.0000 - FalsePositives: 78.0000 - FalseNegatives: 93.0000 - val_loss: 0.2145 - val_accuracy: 0.9187 - val_Precision: 0.9221 - val_Recall: 0.9175 - val_TruePositives: 734.0000 - val_TrueNegatives: 1538.0000 - val_FalsePositives: 62.0000 - val_FalseNegatives: 66.0000
# Epoch 62/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2429 - accuracy: 0.9174 - Precision: 0.9259 - Recall: 0.9062 - TruePositives: 812.0000 - TrueNegatives: 1727.0000 - FalsePositives: 65.0000 - FalseNegatives: 84.0000 - val_loss: 0.2231 - val_accuracy: 0.9150 - val_Precision: 0.9226 - val_Recall: 0.9087 - val_TruePositives: 727.0000 - val_TrueNegatives: 1539.0000 - val_FalsePositives: 61.0000 - val_FalseNegatives: 73.0000
# Epoch 63/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.1844 - accuracy: 0.9323 - Precision: 0.9376 - Recall: 0.9300 - TruePositives: 811.0000 - TrueNegatives: 1690.0000 - FalsePositives: 54.0000 - FalseNegatives: 61.0000 - val_loss: 0.2822 - val_accuracy: 0.8863 - val_Precision: 0.8916 - val_Recall: 0.8838 - val_TruePositives: 707.0000 - val_TrueNegatives: 1514.0000 - val_FalsePositives: 86.0000 - val_FalseNegatives: 93.0000
# Epoch 64/100
# 28/28 [==============================] - 123s 4s/step - loss: 0.2785 - accuracy: 0.8996 - Precision: 0.9098 - Recall: 0.8895 - TruePositives: 797.0000 - TrueNegatives: 1713.0000 - FalsePositives: 79.0000 - FalseNegatives: 99.0000 - val_loss: 0.2626 - val_accuracy: 0.9062 - val_Precision: 0.9083 - val_Recall: 0.9038 - val_TruePositives: 723.0000 - val_TrueNegatives: 1527.0000 - val_FalsePositives: 73.0000 - val_FalseNegatives: 77.0000
# Epoch 65/100
# 28/28 [==============================] - 151s 5s/step - loss: 0.2905 - accuracy: 0.8996 - Precision: 0.9055 - Recall: 0.8873 - TruePositives: 795.0000 - TrueNegatives: 1709.0000 - FalsePositives: 83.0000 - FalseNegatives: 101.0000 - val_loss: 0.3786 - val_accuracy: 0.8325 - val_Precision: 0.8420 - val_Recall: 0.8125 - val_TruePositives: 650.0000 - val_TrueNegatives: 1478.0000 - val_FalsePositives: 122.0000 - val_FalseNegatives: 150.0000
# Epoch 66/100
# 28/28 [==============================] - 134s 5s/step - loss: 0.2576 - accuracy: 0.8979 - Precision: 0.9042 - Recall: 0.8876 - TruePositives: 774.0000 - TrueNegatives: 1662.0000 - FalsePositives: 82.0000 - FalseNegatives: 98.0000 - val_loss: 0.2637 - val_accuracy: 0.8838 - val_Precision: 0.8892 - val_Recall: 0.8725 - val_TruePositives: 698.0000 - val_TrueNegatives: 1513.0000 - val_FalsePositives: 87.0000 - val_FalseNegatives: 102.0000
# Epoch 67/100
# 28/28 [==============================] - 129s 5s/step - loss: 0.2311 - accuracy: 0.9197 - Precision: 0.9241 - Recall: 0.9071 - TruePositives: 791.0000 - TrueNegatives: 1679.0000 - FalsePositives: 65.0000 - FalseNegatives: 81.0000 - val_loss: 0.2704 - val_accuracy: 0.8800 - val_Precision: 0.8892 - val_Recall: 0.8725 - val_TruePositives: 698.0000 - val_TrueNegatives: 1513.0000 - val_FalsePositives: 87.0000 - val_FalseNegatives: 102.0000
# Epoch 68/100
# 28/28 [==============================] - 123s 4s/step - loss: 0.2679 - accuracy: 0.9060 - Precision: 0.9144 - Recall: 0.8945 - TruePositives: 780.0000 - TrueNegatives: 1671.0000 - FalsePositives: 73.0000 - FalseNegatives: 92.0000 - val_loss: 0.2578 - val_accuracy: 0.9150 - val_Precision: 0.9213 - val_Recall: 0.9075 - val_TruePositives: 726.0000 - val_TrueNegatives: 1538.0000 - val_FalsePositives: 62.0000 - val_FalseNegatives: 74.0000
# Epoch 69/100
# 28/28 [==============================] - 129s 5s/step - loss: 0.2717 - accuracy: 0.8940 - Precision: 0.9036 - Recall: 0.8895 - TruePositives: 797.0000 - TrueNegatives: 1707.0000 - FalsePositives: 85.0000 - FalseNegatives: 99.0000 - val_loss: 0.2707 - val_accuracy: 0.8925 - val_Precision: 0.8990 - val_Recall: 0.8900 - val_TruePositives: 712.0000 - val_TrueNegatives: 1520.0000 - val_FalsePositives: 80.0000 - val_FalseNegatives: 88.0000
# Epoch 70/100
# 28/28 [==============================] - 126s 5s/step - loss: 0.2732 - accuracy: 0.8973 - Precision: 0.9044 - Recall: 0.8873 - TruePositives: 795.0000 - TrueNegatives: 1708.0000 - FalsePositives: 84.0000 - FalseNegatives: 101.0000 - val_loss: 0.3715 - val_accuracy: 0.8438 - val_Precision: 0.8546 - val_Recall: 0.8375 - val_TruePositives: 670.0000 - val_TrueNegatives: 1486.0000 - val_FalsePositives: 114.0000 - val_FalseNegatives: 130.0000
# Epoch 71/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.2583 - accuracy: 0.9071 - Precision: 0.9138 - Recall: 0.8991 - TruePositives: 784.0000 - TrueNegatives: 1670.0000 - FalsePositives: 74.0000 - FalseNegatives: 88.0000 - val_loss: 0.3548 - val_accuracy: 0.8375 - val_Precision: 0.8437 - val_Recall: 0.8300 - val_TruePositives: 664.0000 - val_TrueNegatives: 1477.0000 - val_FalsePositives: 123.0000 - val_FalseNegatives: 136.0000
# Epoch 72/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2105 - accuracy: 0.9151 - Precision: 0.9188 - Recall: 0.9083 - TruePositives: 792.0000 - TrueNegatives: 1674.0000 - FalsePositives: 70.0000 - FalseNegatives: 80.0000 - val_loss: 0.2362 - val_accuracy: 0.9075 - val_Precision: 0.9094 - val_Recall: 0.9038 - val_TruePositives: 723.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 77.0000
# Epoch 73/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2299 - accuracy: 0.9174 - Precision: 0.9223 - Recall: 0.9141 - TruePositives: 819.0000 - TrueNegatives: 1723.0000 - FalsePositives: 69.0000 - FalseNegatives: 77.0000 - val_loss: 0.2414 - val_accuracy: 0.8825 - val_Precision: 0.8847 - val_Recall: 0.8825 - val_TruePositives: 706.0000 - val_TrueNegatives: 1508.0000 - val_FalsePositives: 92.0000 - val_FalseNegatives: 94.0000
# Epoch 74/100
# 28/28 [==============================] - 123s 4s/step - loss: 0.2478 - accuracy: 0.9106 - Precision: 0.9145 - Recall: 0.9071 - TruePositives: 791.0000 - TrueNegatives: 1670.0000 - FalsePositives: 74.0000 - FalseNegatives: 81.0000 - val_loss: 0.2492 - val_accuracy: 0.8863 - val_Precision: 0.8897 - val_Recall: 0.8775 - val_TruePositives: 702.0000 - val_TrueNegatives: 1513.0000 - val_FalsePositives: 87.0000 - val_FalseNegatives: 98.0000
# Epoch 75/100
# 28/28 [==============================] - 125s 4s/step - loss: 0.2471 - accuracy: 0.9096 - Precision: 0.9152 - Recall: 0.9029 - TruePositives: 809.0000 - TrueNegatives: 1717.0000 - FalsePositives: 75.0000 - FalseNegatives: 87.0000 - val_loss: 0.2099 - val_accuracy: 0.9175 - val_Precision: 0.9216 - val_Recall: 0.9112 - val_TruePositives: 729.0000 - val_TrueNegatives: 1538.0000 - val_FalsePositives: 62.0000 - val_FalseNegatives: 71.0000
# Epoch 76/100
# 28/28 [==============================] - 117s 4s/step - loss: 0.2347 - accuracy: 0.9163 - Precision: 0.9260 - Recall: 0.9037 - TruePositives: 788.0000 - TrueNegatives: 1681.0000 - FalsePositives: 63.0000 - FalseNegatives: 84.0000 - val_loss: 0.2780 - val_accuracy: 0.8813 - val_Precision: 0.8854 - val_Recall: 0.8788 - val_TruePositives: 703.0000 - val_TrueNegatives: 1509.0000 - val_FalsePositives: 91.0000 - val_FalseNegatives: 97.0000
# Epoch 77/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.1949 - accuracy: 0.9297 - Precision: 0.9303 - Recall: 0.9241 - TruePositives: 828.0000 - TrueNegatives: 1730.0000 - FalsePositives: 62.0000 - FalseNegatives: 68.0000 - val_loss: 0.2063 - val_accuracy: 0.9275 - val_Precision: 0.9296 - val_Recall: 0.9250 - val_TruePositives: 740.0000 - val_TrueNegatives: 1544.0000 - val_FalsePositives: 56.0000 - val_FalseNegatives: 60.0000
# Epoch 78/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2764 - accuracy: 0.9025 - Precision: 0.9089 - Recall: 0.8922 - TruePositives: 778.0000 - TrueNegatives: 1666.0000 - FalsePositives: 78.0000 - FalseNegatives: 94.0000 - val_loss: 0.2511 - val_accuracy: 0.8950 - val_Precision: 0.8965 - val_Recall: 0.8875 - val_TruePositives: 710.0000 - val_TrueNegatives: 1518.0000 - val_FalsePositives: 82.0000 - val_FalseNegatives: 90.0000
# Epoch 79/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.2529 - accuracy: 0.8984 - Precision: 0.9076 - Recall: 0.8884 - TruePositives: 796.0000 - TrueNegatives: 1711.0000 - FalsePositives: 81.0000 - FalseNegatives: 100.0000 - val_loss: 0.2467 - val_accuracy: 0.9025 - val_Precision: 0.9029 - val_Recall: 0.8950 - val_TruePositives: 716.0000 - val_TrueNegatives: 1523.0000 - val_FalsePositives: 77.0000 - val_FalseNegatives: 84.0000
# Epoch 80/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2424 - accuracy: 0.9141 - Precision: 0.9200 - Recall: 0.9118 - TruePositives: 817.0000 - TrueNegatives: 1721.0000 - FalsePositives: 71.0000 - FalseNegatives: 79.0000 - val_loss: 0.2127 - val_accuracy: 0.9150 - val_Precision: 0.9180 - val_Recall: 0.9100 - val_TruePositives: 728.0000 - val_TrueNegatives: 1535.0000 - val_FalsePositives: 65.0000 - val_FalseNegatives: 72.0000
# Epoch 81/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2289 - accuracy: 0.9140 - Precision: 0.9196 - Recall: 0.9048 - TruePositives: 789.0000 - TrueNegatives: 1675.0000 - FalsePositives: 69.0000 - FalseNegatives: 83.0000 - val_loss: 0.2265 - val_accuracy: 0.9100 - val_Precision: 0.9141 - val_Recall: 0.9050 - val_TruePositives: 724.0000 - val_TrueNegatives: 1532.0000 - val_FalsePositives: 68.0000 - val_FalseNegatives: 76.0000
# Epoch 82/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2497 - accuracy: 0.8922 - Precision: 0.8999 - Recall: 0.8865 - TruePositives: 773.0000 - TrueNegatives: 1658.0000 - FalsePositives: 86.0000 - FalseNegatives: 99.0000 - val_loss: 0.2465 - val_accuracy: 0.8900 - val_Precision: 0.8965 - val_Recall: 0.8875 - val_TruePositives: 710.0000 - val_TrueNegatives: 1518.0000 - val_FalsePositives: 82.0000 - val_FalseNegatives: 90.0000
# Epoch 83/100
# 28/28 [==============================] - 118s 4s/step - loss: 0.2534 - accuracy: 0.9037 - Precision: 0.9044 - Recall: 0.9002 - TruePositives: 785.0000 - TrueNegatives: 1661.0000 - FalsePositives: 83.0000 - FalseNegatives: 87.0000 - val_loss: 0.1797 - val_accuracy: 0.9388 - val_Precision: 0.9421 - val_Recall: 0.9362 - val_TruePositives: 749.0000 - val_TrueNegatives: 1554.0000 - val_FalsePositives: 46.0000 - val_FalseNegatives: 51.0000
# Epoch 84/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2058 - accuracy: 0.9174 - Precision: 0.9220 - Recall: 0.9107 - TruePositives: 816.0000 - TrueNegatives: 1723.0000 - FalsePositives: 69.0000 - FalseNegatives: 80.0000 - val_loss: 0.2153 - val_accuracy: 0.9162 - val_Precision: 0.9161 - val_Recall: 0.9150 - val_TruePositives: 732.0000 - val_TrueNegatives: 1533.0000 - val_FalsePositives: 67.0000 - val_FalseNegatives: 68.0000
# Epoch 85/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.2096 - accuracy: 0.9232 - Precision: 0.9263 - Recall: 0.9220 - TruePositives: 804.0000 - TrueNegatives: 1680.0000 - FalsePositives: 64.0000 - FalseNegatives: 68.0000 - val_loss: 0.2133 - val_accuracy: 0.9112 - val_Precision: 0.9144 - val_Recall: 0.9075 - val_TruePositives: 726.0000 - val_TrueNegatives: 1532.0000 - val_FalsePositives: 68.0000 - val_FalseNegatives: 74.0000
# Epoch 86/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.1804 - accuracy: 0.9381 - Precision: 0.9444 - Recall: 0.9346 - TruePositives: 815.0000 - TrueNegatives: 1696.0000 - FalsePositives: 48.0000 - FalseNegatives: 57.0000 - val_loss: 0.2219 - val_accuracy: 0.9125 - val_Precision: 0.9124 - val_Recall: 0.9112 - val_TruePositives: 729.0000 - val_TrueNegatives: 1530.0000 - val_FalsePositives: 70.0000 - val_FalseNegatives: 71.0000
# Epoch 87/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2197 - accuracy: 0.9197 - Precision: 0.9280 - Recall: 0.9163 - TruePositives: 799.0000 - TrueNegatives: 1682.0000 - FalsePositives: 62.0000 - FalseNegatives: 73.0000 - val_loss: 0.2554 - val_accuracy: 0.9062 - val_Precision: 0.9106 - val_Recall: 0.9038 - val_TruePositives: 723.0000 - val_TrueNegatives: 1529.0000 - val_FalsePositives: 71.0000 - val_FalseNegatives: 77.0000
# Epoch 88/100
# 28/28 [==============================] - 120s 4s/step - loss: 0.2830 - accuracy: 0.8911 - Precision: 0.8985 - Recall: 0.8830 - TruePositives: 770.0000 - TrueNegatives: 1657.0000 - FalsePositives: 87.0000 - FalseNegatives: 102.0000 - val_loss: 0.2441 - val_accuracy: 0.9100 - val_Precision: 0.9139 - val_Recall: 0.9025 - val_TruePositives: 722.0000 - val_TrueNegatives: 1532.0000 - val_FalsePositives: 68.0000 - val_FalseNegatives: 78.0000
# Epoch 89/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2629 - accuracy: 0.9014 - Precision: 0.9141 - Recall: 0.8911 - TruePositives: 777.0000 - TrueNegatives: 1671.0000 - FalsePositives: 73.0000 - FalseNegatives: 95.0000 - val_loss: 0.2694 - val_accuracy: 0.8913 - val_Precision: 0.8977 - val_Recall: 0.8888 - val_TruePositives: 711.0000 - val_TrueNegatives: 1519.0000 - val_FalsePositives: 81.0000 - val_FalseNegatives: 89.0000
# Epoch 90/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2245 - accuracy: 0.9128 - Precision: 0.9230 - Recall: 0.9071 - TruePositives: 791.0000 - TrueNegatives: 1678.0000 - FalsePositives: 66.0000 - FalseNegatives: 81.0000 - val_loss: 0.2430 - val_accuracy: 0.9013 - val_Precision: 0.9064 - val_Recall: 0.8963 - val_TruePositives: 717.0000 - val_TrueNegatives: 1526.0000 - val_FalsePositives: 74.0000 - val_FalseNegatives: 83.0000
# Epoch 91/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.1889 - accuracy: 0.9300 - Precision: 0.9370 - Recall: 0.9209 - TruePositives: 803.0000 - TrueNegatives: 1690.0000 - FalsePositives: 54.0000 - FalseNegatives: 69.0000 - val_loss: 0.2451 - val_accuracy: 0.9062 - val_Precision: 0.9083 - val_Recall: 0.9038 - val_TruePositives: 723.0000 - val_TrueNegatives: 1527.0000 - val_FalsePositives: 73.0000 - val_FalseNegatives: 77.0000
# Epoch 92/100
# 28/28 [==============================] - 126s 4s/step - loss: 0.2169 - accuracy: 0.9141 - Precision: 0.9205 - Recall: 0.9051 - TruePositives: 811.0000 - TrueNegatives: 1722.0000 - FalsePositives: 70.0000 - FalseNegatives: 85.0000 - val_loss: 0.2393 - val_accuracy: 0.9075 - val_Precision: 0.9095 - val_Recall: 0.9050 - val_TruePositives: 724.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 76.0000
# Epoch 93/100
# 28/28 [==============================] - 126s 5s/step - loss: 0.2183 - accuracy: 0.9208 - Precision: 0.9253 - Recall: 0.9118 - TruePositives: 817.0000 - TrueNegatives: 1726.0000 - FalsePositives: 66.0000 - FalseNegatives: 79.0000 - val_loss: 0.2697 - val_accuracy: 0.8988 - val_Precision: 0.8996 - val_Recall: 0.8963 - val_TruePositives: 717.0000 - val_TrueNegatives: 1520.0000 - val_FalsePositives: 80.0000 - val_FalseNegatives: 83.0000
# Epoch 94/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2065 - accuracy: 0.9278 - Precision: 0.9337 - Recall: 0.9209 - TruePositives: 803.0000 - TrueNegatives: 1687.0000 - FalsePositives: 57.0000 - FalseNegatives: 69.0000 - val_loss: 0.2352 - val_accuracy: 0.9162 - val_Precision: 0.9167 - val_Recall: 0.9075 - val_TruePositives: 726.0000 - val_TrueNegatives: 1534.0000 - val_FalsePositives: 66.0000 - val_FalseNegatives: 74.0000
# Epoch 95/100
# 28/28 [==============================] - 121s 4s/step - loss: 0.2404 - accuracy: 0.9106 - Precision: 0.9164 - Recall: 0.9048 - TruePositives: 789.0000 - TrueNegatives: 1672.0000 - FalsePositives: 72.0000 - FalseNegatives: 83.0000 - val_loss: 0.2240 - val_accuracy: 0.9087 - val_Precision: 0.9099 - val_Recall: 0.9087 - val_TruePositives: 727.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 73.0000
# Epoch 96/100
# 28/28 [==============================] - 124s 4s/step - loss: 0.2149 - accuracy: 0.9219 - Precision: 0.9254 - Recall: 0.9141 - TruePositives: 819.0000 - TrueNegatives: 1726.0000 - FalsePositives: 66.0000 - FalseNegatives: 77.0000 - val_loss: 0.2945 - val_accuracy: 0.8888 - val_Precision: 0.8920 - val_Recall: 0.8875 - val_TruePositives: 710.0000 - val_TrueNegatives: 1514.0000 - val_FalsePositives: 86.0000 - val_FalseNegatives: 90.0000
# Epoch 97/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2717 - accuracy: 0.9060 - Precision: 0.9160 - Recall: 0.9002 - TruePositives: 785.0000 - TrueNegatives: 1672.0000 - FalsePositives: 72.0000 - FalseNegatives: 87.0000 - val_loss: 0.2417 - val_accuracy: 0.9038 - val_Precision: 0.9058 - val_Recall: 0.9013 - val_TruePositives: 721.0000 - val_TrueNegatives: 1525.0000 - val_FalsePositives: 75.0000 - val_FalseNegatives: 79.0000
# Epoch 98/100
# 28/28 [==============================] - 122s 4s/step - loss: 0.2408 - accuracy: 0.9128 - Precision: 0.9169 - Recall: 0.9106 - TruePositives: 794.0000 - TrueNegatives: 1672.0000 - FalsePositives: 72.0000 - FalseNegatives: 78.0000 - val_loss: 0.3142 - val_accuracy: 0.8612 - val_Precision: 0.8632 - val_Recall: 0.8600 - val_TruePositives: 688.0000 - val_TrueNegatives: 1491.0000 - val_FalsePositives: 109.0000 - val_FalseNegatives: 112.0000
# Epoch 99/100
# 28/28 [==============================] - 119s 4s/step - loss: 0.2485 - accuracy: 0.9266 - Precision: 0.9326 - Recall: 0.9209 - TruePositives: 803.0000 - TrueNegatives: 1686.0000 - FalsePositives: 58.0000 - FalseNegatives: 69.0000 - val_loss: 0.2359 - val_accuracy: 0.9175 - val_Precision: 0.9183 - val_Recall: 0.9137 - val_TruePositives: 731.0000 - val_TrueNegatives: 1535.0000 - val_FalsePositives: 65.0000 - val_FalseNegatives: 69.0000
# Epoch 100/100
# 28/28 [==============================] - 117s 4s/step - loss: 0.1989 - accuracy: 0.9243 - Precision: 0.9335 - Recall: 0.9174 - TruePositives: 800.0000 - TrueNegatives: 1687.0000 - FalsePositives: 57.0000 - FalseNegatives: 72.0000 - val_loss: 0.2576 - val_accuracy: 0.9038 - val_Precision: 0.9090 - val_Recall: 0.8988 - val_TruePositives: 719.0000 - val_TrueNegatives: 1528.0000 - val_FalsePositives: 72.0000 - val_FalseNegatives: 81.0000

# %%
import matplotlib.pyplot as plt

# %%
def graph():
    #Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
graph()

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(test_set)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 41/41 [==============================] - 58s 1s/step - loss: 0.2465 - accuracy: 0.9084 - Precision: 0.9137 - Recall: 0.9037 - TruePositives: 1164.0000 - TrueNegatives: 2466.0000 - FalsePositives: 110.0000 - FalseNegatives: 124.0000
# Test Accuracy: 90.83850979804993

# %%
precision=scores[2]
recall=scores[3]
true_positives=scores[3]
true_negatives=scores[4]
false_positives=scores[5]
false_negatives=scores[6]

# %%
confution_matrix=[[true_positives,false_positives],[false_negatives,true_negatives]]

# %%
print(f"Accuracy                     : {scores[1]*100}")
print("")
print("Confution Matrix             : ",confution_matrix)
print("")
print("precision Score              : ",precision)
print("")
print("Recall or Sensitivity Score  : ",recall)
print("")
f1=(precision*recall)/(precision+recall)
F1_Score=2*f1
print("F1 Score                     : ",F1_Score)
print("")
Specifisity=true_negatives/true_negatives+false_positives
print("Specifisity Score            : ",Specifisity)
# Out:
# Accuracy                     : 90.83850979804993
#
# Confution Matrix             :  [[0.9037267, 2466.0], [110.0, 1164.0]]
#
# precision Score              :  0.9136578
#
# Recall or Sensitivity Score  :  0.9037267
#
# F1 Score                     :  0.908665120601654
#
# Specifisity Score            :  2467.0

# %%
import h5py

# %%
model.save('covid8.h5')

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

# %%
classifierLoad=tf.keras.models.load_model('covid8.h5')

# %%
import numpy as np

# %%
from tensorflow.keras.preprocessing import image
test_image=image.load_img('c.jpg',target_size=(224,224))

# %%
import matplotlib.pyplot as plt
img = plt.imshow(test_image)

# %%
test_image=image.img_to_array(test_image)

# %%
test_image=np.expand_dims(test_image,axis=0)

# %%
result=classifierLoad.predict(test_image)

# %%
prediction = result[0]

# %%
classes=training_set.class_indices

# %%
classes
# Out:
# {'COVID19': 0, 'NORMAL': 1, 'PNEUMONIA': 2}

# %%
prediction=list(prediction)

# %%
prediction
# Out:
# [1.0, 0.0, 0.0]

# %%
classes=['COVID19', 'NORMAL', 'PNEUMONIA']

# %%
output=zip(classes,prediction)

# %%
output=dict(output)

# %%
output
# Out:
# {'COVID19': 1.0, 'NORMAL': 0.0, 'PNEUMONIA': 0.0}

# %%
if output['COVID19']==1.0 :
    print("COVID19")
elif output['NORMAL']==1.0:
    print("NORMAL")
elif output['PNEUMONIA']==1.0:
    print("PNEUMONIA")
# Out:
# COVID19
